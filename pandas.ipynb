# %% [markdown]
# <a href="https://colab.research.google.com/github/B-SatheesKumar/Machine_Learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([1,3,5,8,8])
a
# Out:
# array([1, 3, 5, 8, 8])

# %%
type(a)
a[1]
# Out:
# 3

# %%
s=pd.Series([1,3,5,6,3,1])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    3
# 5    1
# dtype: int64

# %%
s[3]
# Out:
# 6

# %%
s.drop(3,inplace=True)

# %%
s.iloc[3]
# Out:
# 3

# %%
s.loc[4]
# Out:
# 3

# %%
a=pd.Series([10,12,13,44,56],index=['a','b','c','a','e'])
a
# Out:
# a    10
# b    12
# c    13
# a    44
# e    56
# dtype: int64

# %%
a['a']
# Out:
# a    10
# a    44
# dtype: int64

# %%
a.loc['a']
# Out:
# a    10
# a    44
# dtype: int64

# %%
a.iloc[1]
# Out:
# 12

# %%
data=[['sathees',20,'20-07-2003'],['bob',None,None],['Alex',None,'23-05-2000']]
data
# Out:
# [['sathees', 20, '20-07-2003'],
#  ['bob', None, None],
#  ['Alex', None, '23-05-2000']]

# %%
df=pd.DataFrame(data)
df
# Out:
#          0     1           2
# 0  sathees  20.0  20-07-2003
# 1      bob   NaN        None
# 2     Alex   NaN  23-05-2000

# %%
df[0:1]
# Out:
#          0     1           2
# 0  sathees  20.0  20-07-2003

# %%
df[0][0]
# Out:
# 'sathees'

# %%
df[[0,2]]
# Out:
#          0           2
# 0  sathees  20-07-2003
# 1      bob        None
# 2     Alex  23-05-2000

# %%
df[1:2]
# Out:
#      0   1     2
# 1  bob NaN  None

# %%
df=pd.DataFrame(data,columns=['Name','Age','DOB'])
df
# Out:
#       Name   Age         DOB
# 0  sathees  20.0  20-07-2003
# 1      bob   NaN        None
# 2     Alex   NaN  23-05-2000

# %%
df['Name']
# Out:
# 0    sathees
# 1        bob
# 2       Alex
# Name: Name, dtype: object

# %%
df['Age']
# Out:
# 0    20.0
# 1     NaN
# 2     NaN
# Name: Age, dtype: float64

# %%
df['Name'][0]
# Out:
# 'sathees'

# %%
df.iloc[0,0]
# Out:
# 'sathees'

# %%
df[0:1][1:1]
# Out:
# Empty DataFrame
# Columns: [Name, Age, DOB]
# Index: []

# %%
s=pd.Series([1,2,38,40])
s
# Out:
# 0     1
# 1     2
# 2    38
# 3    40
# dtype: int64

# %%
s.plot()
s.hist(bins=2)
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
n=s.to_numpy()

# %%
type(n)
# Out:
# numpy.ndarray

# %%
df.head(1)
# Out:
#       Name   Age         DOB
# 0  sathees  20.0  20-07-2003

# %%
df.tail(1)
# Out:
#    Name  Age         DOB
# 2  Alex  NaN  23-05-2000

# %%
# None,'','-','?','Null',np.nan(not a number)

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     2
# DOB     1
# dtype: int64

# %%
df
# Out:
#       Name   Age         DOB
# 0  sathees  20.0  20-07-2003
# 1      bob   NaN        None
# 2     Alex   NaN  23-05-2000

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     2
# DOB     1
# dtype: int64

# %%
df.dropna()
# Out:
#       Name   Age         DOB
# 0  sathees  20.0  20-07-2003

# %%
df
# Out:
#       Name   Age         DOB
# 0  sathees  20.0  20-07-2003
# 1      bob   NaN        None
# 2     Alex   NaN  23-05-2000

# %%
df.drop(['Age'],axis=1,inplace=True)
df
# Out:
#       Name         DOB
# 0  sathees  20-07-2003
# 1      bob        None
# 2     Alex  23-05-2000

# %%
df.drop([0,2])
# Out:
#   Name   DOB
# 1  bob  None

# %%
a
# Out:
# a    10
# b    12
# c    13
# a    44
# e    56
# dtype: int64

# %%
a1=np.array([1,2,46,89,4])
a1>40
a1[a1>40]
# Out:
# array([46, 89])

# %%
a1[a%2!=0]
# Out:
# array([46])

# %%
b=np.array([2,4,78,6,42,5,6,78,7,5,3,2])
b>40
# Out:
# array([False, False,  True, False,  True, False, False,  True, False,
#        False, False, False])

# %%
b[b>40]
# Out:
# array([78, 42, 78])

# %%
b[b%2==0]
# Out:
# array([ 2,  4, 78,  6, 42,  6, 78,  2])

# %%
df
# Out:
#       Name         DOB
# 0  sathees  20-07-2003
# 1      bob        None
# 2     Alex  23-05-2000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   DOB     2 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
df['Name'].str.contains('e')
# Out:
# 0     True
# 1    False
# 2     True
# Name: Name, dtype: bool

# %%
df['Name'].str.contains('b')
# Out:
# 0    False
# 1     True
# 2    False
# Name: Name, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (3, 2)
# 6
# [RangeIndex(start=0, stop=3, step=1), Index(['Name', 'DOB'], dtype='object')]
# 2
# Name    object
# DOB     object
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'DOB'], dtype='object')
# [['sathees' '20-07-2003']
#  ['bob' None]
#  ['Alex' '23-05-2000']]

# %%
df
# Out:
#       Name         DOB
# 0  sathees  20-07-2003
# 1      bob        None
# 2     Alex  23-05-2000

# %%
df2=pd.concat([df,df])
df2
# Out:
#       Name         DOB
# 0  sathees  20-07-2003
# 1      bob        None
# 2     Alex  23-05-2000
# 0  sathees  20-07-2003
# 1      bob        None
# 2     Alex  23-05-2000

# %%
df.describe()
# Out:
#            Name         DOB
# count         3           2
# unique        3           2
# top     sathees  20-07-2003
# freq          1           1

# %%
df['Name']
# Out:
# 0    sathees
# 1        bob
# 2       Alex
# Name: Name, dtype: object

# %%
df.DOB
# Out:
# 0    20-07-2003
# 1          None
# 2    23-05-2000
# Name: DOB, dtype: object

# %%
df['DOB'][0]
# Out:
# '20-07-2003'

# %%
df[['Name','DOB']]
# Out:
#       Name         DOB
# 0  sathees  20-07-2003
# 1      bob        None
# 2     Alex  23-05-2000

# %%
df.loc[0][0]
# Out:
# 'sathees'

# %%
df.loc[0,'Name']
# Out:
# 'sathees'

# %%
df.iloc[0,0]
# Out:
# 'sathees'

# %%
df.iloc[0,1]
# Out:
# '20-07-2003'

# %%
df['DOB'][1]='23-5-2006'

# %%
df
# Out:
#       Name         DOB
# 0  sathees  20-07-2003
# 1      bob   23-5-2006
# 2     Alex  23-05-2000

# %%
f=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
f
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
type(f)
# Out:
# list

# %%
type(f.item_name)
# Out:
# pandas.core.series.Series

# %%
f.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
f.item_price=f.item_price.str.replace('$','')
f.head(10)
# Out:
# <ipython-input-85-a9fafb024ffb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   f.item_price=f.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
f.item_price=f.item_price.astype(float)
f
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
type(f.item_price[0])
# Out:
# numpy.float64

# %%
print(f.item_price*100)
f
# Out:
# 0        239.0
# 1        339.0
# 2        339.0
# 3        239.0
# 4       1698.0
#          ...
# 4617    1175.0
# 4618    1175.0
# 4619    1125.0
# 4620     875.0
# 4621     875.0
# Name: item_price, Length: 4622, dtype: float64
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# ...

# %%
f_drink=f[f.item_price<1.1]
f_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
f_drink.item_name.nunique()
# Out:
# 2

# %%
f[f.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
f.dropna(inplace=True)

# %%
f[f.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
f[(f.item_price < 10) & (f.item_name=='Chicken Bowl')].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
d=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
d.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
d[(d.star_rating>=8)]
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 3            9.0           The Dark Knight          PG-13     Action
# 4            8.9              Pulp Fiction              R      Crime
# ..           ...                       ...            ...        ...
# 389          8.0                    Freaks        UNRATED      Drama
# 390          8.0     Letters from Iwo Jima              R      Drama
# 391          8.0          Edge of Tomorrow          PG-13     Action
# 392          8.0                     Glory              R      Drama
# 393          8.0         The African Queen             PG  Adventure
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
d[(d.star_rating>=8)&(d.genre=="Action")]
# Out:
#      star_rating                                           title  \
# 3            9.0                                 The Dark Knight
# 11           8.8                                       Inception
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 20           8.7                                      The Matrix
# 36           8.6                             Saving Private Ryan
# 37           8.6                         Raiders of the Lost Ark
# 43           8.5                           The Dark Knight Rises
# 44           8.5                                       Gladiator
# 45           8.5                      Terminator 2: Judgment Day
# 75           8.4                                          Aliens
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 82           8.4                                      Braveheart
# ...

# %%
d[(d.star_rating>=8)&(d.genre=="Action")&(d.actors_list.str.contains('Robert Downey Jr.'))].sort_values(['duration'])
# Out:
#      star_rating         title content_rating   genre  duration  \
# 177          8.2  The Avengers          PG-13  Action       143
#
#                                            actors_list
# 177  [u'Robert Downey Jr.', u'Chris Evans', u'Scarl...

# %%
d[d.actors_list.str.contains('Christian Bale')].sort_values(['star_rating','duration'],ascending=(False,True))
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 3            9.0        The Dark Knight          PG-13     Action       152
# 53           8.5           The Prestige          PG-13      Drama       130
# 43           8.5  The Dark Knight Rises          PG-13     Action       165
# 113          8.3          Batman Begins          PG-13     Action       140
# 446          7.9            The Fighter              R  Biography       116
# 555          7.8           3:10 to Yuma              R  Adventure       122
# 504          7.8      Empire of the Sun             PG      Drama       153
# 589          7.7          The Machinist              R      Drama       101
# 732          7.6        American Psycho              R      Crime       102
# 815          7.6            Equilibrium              R     Action       107
# 702          7.6  Jin ling shi san chai              R      Drama       146
#
#                                            actors_list
# ...

# %%
x=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
x
# Out:
#        City,Colors Reported,Shape Reported,State,Time
# 0                  Ithaca,,TRIANGLE,NY,6/1/1930 22:00
# 1               Willingboro,,OTHER,NJ,6/30/1930 20:00
# 2                    Holyoke,,OVAL,CO,2/15/1931 14:00
# 3                     Abilene,,DISK,KS,6/1/1931 13:00
# 4      New York Worlds Fair,,LIGHT,NY,4/18/1933 19:00
# ...                                               ...
# 18236        Grant Park,,TRIANGLE,IL,12/31/2000 23:00
# 18237           Spirit Lake,,DISK,IA,12/31/2000 23:00
# 18238               Eagle River,,,WI,12/31/2000 23:45
# 18239       Eagle River,RED,LIGHT,WI,12/31/2000 23:45
# 18240                  Ybor,,OVAL,FL,12/31/2000 23:59
#
# [18241 rows x 1 columns]

# %%
x.dropna(how="all")
# Out:
#        City,Colors Reported,Shape Reported,State,Time
# 0                  Ithaca,,TRIANGLE,NY,6/1/1930 22:00
# 1               Willingboro,,OTHER,NJ,6/30/1930 20:00
# 2                    Holyoke,,OVAL,CO,2/15/1931 14:00
# 3                     Abilene,,DISK,KS,6/1/1931 13:00
# 4      New York Worlds Fair,,LIGHT,NY,4/18/1933 19:00
# ...                                               ...
# 18236        Grant Park,,TRIANGLE,IL,12/31/2000 23:00
# 18237           Spirit Lake,,DISK,IA,12/31/2000 23:00
# 18238               Eagle River,,,WI,12/31/2000 23:45
# 18239       Eagle River,RED,LIGHT,WI,12/31/2000 23:45
# 18240                  Ybor,,OVAL,FL,12/31/2000 23:59
#
# [18241 rows x 1 columns]

# %%
#x.dropna(subset=['City','Shape Reported'],how='any').shape

# %%
drinks=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks[drinks.continent=="Asia"]
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# ...

# %%
drinks[drinks.continent=="Asia"].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent=="Asia"].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.describe()
# Out:
#                count        mean        std   min     25%    50%     75%  \
# continent
# Africa          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# Asia            44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# Europe          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# North America   23.0  145.434783  79.621163   1.0   80.00  143.0  198.00
# Oceania         16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# South America   12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#                  max
# continent
# Africa         376.0
# Asia           247.0
# Europe         361.0
# North America  285.0
# Oceania        306.0
# South America  333.0
